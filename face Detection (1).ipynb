# %%
import cv2
import numpy as np
import tensorflow as tf
import pymongo
from datetime import datetime
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from scipy.spatial.distance import cosine


client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["AttendanceSystem"]
userCOLLECTION = db["Users"]
CollectionATTANDANCE = db["Attendance"]


base_model = MobileNetV2(weights="imagenet", include_top=False, pooling="avg")

def faceEmba(facePIC):
    facePIC = cv2.resize(facePIC, (224, 224))
    facePIC = img_to_array(facePIC)
    facePIC = preprocess_input(facePIC)
    facePIC = np.expand_dims(facePIC, axis=0)
    embedding = base_model.predict(facePIC)[0]
    return embedding


def userdata(name, facePIC):
    embedding = faceEmba(facePIC)
    userENTRED = {"name": name, "embedding": embedding.tolist()}  
    userCOLLECTION.insert_one(userENTRED)
    print(f"{name}'s face embedding!")


def regSystem(faceDATA):
    users = userCOLLECTION.find({})
    bestMATCH = None
    BESTsimilarity = 0
    
    for user in users:
        STOREDemb = np.array(user["embedding"])
        similarity = 1 - cosine(faceDATA, STOREDemb)  
        print(f"{user['name']}: Similarity = {similarity:.4f}") 
        
        if similarity > 0.35 and similarity > BESTsimilarity: 
            bestMATCH = user["name"]
            BESTsimilarity = similarity
    
    return bestMATCH


def mark_attendance(name):
    MarkedDATE = str(datetime.today().date())
    alreadyMARKED = CollectionATTANDANCE.find_one({"name": name, "date": MarkedDATE})
    
    if not alreadyMARKED:
        attandanceENTRY = {
            "name": name,
            "date": MarkedDATE,
            "time": str(datetime.now().strftime("%H:%M:%S"))
        }
        CollectionATTANDANCE.insert_one(attandanceENTRY)
        print(f"Attendance Marked: {name}")
    else:
        print(f"{name}'s attendance already marked today.")


face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")


cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        face = frame[y:y+h, x:x+w]
        faceDATA = faceEmba(face)
        name = regSystem(faceDATA)

        if name:
            mark_attendance(name)
            text = f"Recognized: {name}"
            color = (0, 255, 0)
        else:
            text = "Unknown"
            color = (0, 0, 255)

        cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
        cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    cv2.imshow("Face Recognition Attendance", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_9440\3645541398.py:18: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights="imagenet", include_top=False, pooling="avg")
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# soham: Similarity = 0.5238
# soham,mmm: Similarity = 0.4943
# soham newww : Similarity = 0.4820
# Somchandra Samanta: Similarity = 0.4164
# Som: Similarity = 0.4795
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# soham: Similarity = 0.5503
# soham,mmm: Similarity = 0.5130
# soham newww : Similarity = 0.5462
# Somchandra Samanta: Similarity = 0.4753
# Som: Similarity = 0.5469
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# soham: Similarity = 0.5779
# soham,mmm: Similarity = 0.5296
# soham newww : Similarity = 0.5600
# Somchandra Samanta: Similarity = 0.4841
# Som: Similarity = 0.5470
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# soham: Similarity = 0.5814
# soham,mmm: Similarity = 0.5368
# soham newww : Similarity = 0.5713
# Somchandra Samanta: Similarity = 0.5097
# Som: Similarity = 0.5517
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# soham: Similarity = 0.5811
# soham,mmm: Similarity = 0.5376
# soham newww : Similarity = 0.5719
# Somchandra Samanta: Similarity = 0.5182
# Som: Similarity = 0.5727
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# soham: Similarity = 0.5780
# soham,mmm: Similarity = 0.5306
# soham newww : Similarity = 0.5639
# Somchandra Samanta: Similarity = 0.5044
# Som: Similarity = 0.5635
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# soham: Similarity = 0.5828
# soham,mmm: Similarity = 0.5381
# soham newww : Similarity = 0.5730
# Somchandra Samanta: Similarity = 0.5090
# Som: Similarity = 0.5637
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# soham: Similarity = 0.5628
# soham,mmm: Similarity = 0.5180
# soham newww : Similarity = 0.5456
# Somchandra Samanta: Similarity = 0.4985
# Som: Similarity = 0.5465
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# soham: Similarity = 0.5745
# soham,mmm: Similarity = 0.5225
# soham newww : Similarity = 0.5497
# Somchandra Samanta: Similarity = 0.4914
# Som: Similarity = 0.5439
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# soham: Similarity = 0.5671
# soham,mmm: Similarity = 0.5227
# soham newww : Similarity = 0.5569
# Somchandra Samanta: Similarity = 0.5060
# Som: Similarity = 0.5482
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5628
# soham,mmm: Similarity = 0.5164
# soham newww : Similarity = 0.5484
# Somchandra Samanta: Similarity = 0.4886
# Som: Similarity = 0.5420
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5711
# soham,mmm: Similarity = 0.5178
# soham newww : Similarity = 0.5392
# Somchandra Samanta: Similarity = 0.4832
# Som: Similarity = 0.5322
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5615
# soham,mmm: Similarity = 0.5216
# soham newww : Similarity = 0.5574
# Somchandra Samanta: Similarity = 0.4979
# Som: Similarity = 0.5475
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5551
# soham,mmm: Similarity = 0.5100
# soham newww : Similarity = 0.5407
# Somchandra Samanta: Similarity = 0.5001
# Som: Similarity = 0.5468
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5722
# soham,mmm: Similarity = 0.5235
# soham newww : Similarity = 0.5549
# Somchandra Samanta: Similarity = 0.5067
# Som: Similarity = 0.5539
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5728
# soham,mmm: Similarity = 0.5310
# soham newww : Similarity = 0.5687
# Somchandra Samanta: Similarity = 0.5178
# Som: Similarity = 0.5782
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5801
# soham,mmm: Similarity = 0.5338
# soham newww : Similarity = 0.5680
# Somchandra Samanta: Similarity = 0.5102
# Som: Similarity = 0.5634
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# soham: Similarity = 0.5626
# soham,mmm: Similarity = 0.5175
# soham newww : Similarity = 0.5516
# Somchandra Samanta: Similarity = 0.5085
# Som: Similarity = 0.5524
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5575
# soham,mmm: Similarity = 0.5120
# soham newww : Similarity = 0.5447
# Somchandra Samanta: Similarity = 0.5023
# Som: Similarity = 0.5537
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5849
# soham,mmm: Similarity = 0.5332
# soham newww : Similarity = 0.5644
# Somchandra Samanta: Similarity = 0.5139
# Som: Similarity = 0.5778
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5627
# soham,mmm: Similarity = 0.5233
# soham newww : Similarity = 0.5595
# Somchandra Samanta: Similarity = 0.5193
# Som: Similarity = 0.5664
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5694
# soham,mmm: Similarity = 0.5241
# soham newww : Similarity = 0.5649
# Somchandra Samanta: Similarity = 0.5196
# Som: Similarity = 0.5724
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5632
# soham,mmm: Similarity = 0.5195
# soham newww : Similarity = 0.5467
# Somchandra Samanta: Similarity = 0.4962
# Som: Similarity = 0.5482
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5632
# soham,mmm: Similarity = 0.5195
# soham newww : Similarity = 0.5467
# Somchandra Samanta: Similarity = 0.4962
# Som: Similarity = 0.5482
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5598
# soham,mmm: Similarity = 0.5144
# soham newww : Similarity = 0.5492
# Somchandra Samanta: Similarity = 0.4964
# Som: Similarity = 0.5507
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5767
# soham,mmm: Similarity = 0.5272
# soham newww : Similarity = 0.5692
# Somchandra Samanta: Similarity = 0.5145
# Som: Similarity = 0.5718
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5840
# soham,mmm: Similarity = 0.5388
# soham newww : Similarity = 0.5696
# Somchandra Samanta: Similarity = 0.5298
# Som: Similarity = 0.5852
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5912
# soham,mmm: Similarity = 0.5374
# soham newww : Similarity = 0.5708
# Somchandra Samanta: Similarity = 0.5163
# Som: Similarity = 0.5738
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5964
# soham,mmm: Similarity = 0.5451
# soham newww : Similarity = 0.5850
# Somchandra Samanta: Similarity = 0.5236
# Som: Similarity = 0.5766
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5688
# soham,mmm: Similarity = 0.5225
# soham newww : Similarity = 0.5583
# Somchandra Samanta: Similarity = 0.5097
# Som: Similarity = 0.5633
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5746
# soham,mmm: Similarity = 0.5285
# soham newww : Similarity = 0.5581
# Somchandra Samanta: Similarity = 0.4946
# Som: Similarity = 0.5548
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5908
# soham,mmm: Similarity = 0.5391
# soham newww : Similarity = 0.5725
# Somchandra Samanta: Similarity = 0.5159
# Som: Similarity = 0.5739
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5601
# soham,mmm: Similarity = 0.5139
# soham newww : Similarity = 0.5463
# Somchandra Samanta: Similarity = 0.5014
# Som: Similarity = 0.5484
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5732
# soham,mmm: Similarity = 0.5240
# soham newww : Similarity = 0.5567
# Somchandra Samanta: Similarity = 0.5006
# Som: Similarity = 0.5528
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5795
# soham,mmm: Similarity = 0.5304
# soham newww : Similarity = 0.5621
# Somchandra Samanta: Similarity = 0.5116
# Som: Similarity = 0.5694
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5681
# soham,mmm: Similarity = 0.5251
# soham newww : Similarity = 0.5590
# Somchandra Samanta: Similarity = 0.4986
# Som: Similarity = 0.5521
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5681
# soham,mmm: Similarity = 0.5251
# soham newww : Similarity = 0.5590
# Somchandra Samanta: Similarity = 0.4986
# Som: Similarity = 0.5521
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# soham: Similarity = 0.5890
# soham,mmm: Similarity = 0.5392
# soham newww : Similarity = 0.5651
# Somchandra Samanta: Similarity = 0.5132
# Som: Similarity = 0.5734
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5622
# soham,mmm: Similarity = 0.5179
# soham newww : Similarity = 0.5508
# Somchandra Samanta: Similarity = 0.4959
# Som: Similarity = 0.5521
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5579
# soham,mmm: Similarity = 0.5135
# soham newww : Similarity = 0.5430
# Somchandra Samanta: Similarity = 0.4890
# Som: Similarity = 0.5425
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# soham: Similarity = 0.5576
# soham,mmm: Similarity = 0.5195
# soham newww : Similarity = 0.5468
# Somchandra Samanta: Similarity = 0.4940
# Som: Similarity = 0.5428
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# soham: Similarity = 0.5840
# soham,mmm: Similarity = 0.5432
# soham newww : Similarity = 0.5812
# Somchandra Samanta: Similarity = 0.5212
# Som: Similarity = 0.5711
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# soham: Similarity = 0.5708
# soham,mmm: Similarity = 0.5225
# soham newww : Similarity = 0.5501
# Somchandra Samanta: Similarity = 0.4985
# Som: Similarity = 0.5476
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# soham: Similarity = 0.5806
# soham,mmm: Similarity = 0.5340
# soham newww : Similarity = 0.5677
# Somchandra Samanta: Similarity = 0.5051
# Som: Similarity = 0.5585
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5747
# soham,mmm: Similarity = 0.5321
# soham newww : Similarity = 0.5666
# Somchandra Samanta: Similarity = 0.5166
# Som: Similarity = 0.5583
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5824
# soham,mmm: Similarity = 0.5391
# soham newww : Similarity = 0.5775
# Somchandra Samanta: Similarity = 0.5237
# Som: Similarity = 0.5735
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5698
# soham,mmm: Similarity = 0.5204
# soham newww : Similarity = 0.5596
# Somchandra Samanta: Similarity = 0.5028
# Som: Similarity = 0.5474
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5840
# soham,mmm: Similarity = 0.5382
# soham newww : Similarity = 0.5719
# Somchandra Samanta: Similarity = 0.5185
# Som: Similarity = 0.5683
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# soham: Similarity = 0.5771
# soham,mmm: Similarity = 0.5307
# soham newww : Similarity = 0.5620
# Somchandra Samanta: Similarity = 0.5025
# Som: Similarity = 0.5579
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5905
# soham,mmm: Similarity = 0.5430
# soham newww : Similarity = 0.5813
# Somchandra Samanta: Similarity = 0.5228
# Som: Similarity = 0.5686
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5754
# soham,mmm: Similarity = 0.5254
# soham newww : Similarity = 0.5568
# Somchandra Samanta: Similarity = 0.5091
# Som: Similarity = 0.5583
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5769
# soham,mmm: Similarity = 0.5298
# soham newww : Similarity = 0.5600
# Somchandra Samanta: Similarity = 0.5174
# Som: Similarity = 0.5666
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5794
# soham,mmm: Similarity = 0.5329
# soham newww : Similarity = 0.5699
# Somchandra Samanta: Similarity = 0.5059
# Som: Similarity = 0.5560
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5794
# soham,mmm: Similarity = 0.5329
# soham newww : Similarity = 0.5699
# Somchandra Samanta: Similarity = 0.5059
# Som: Similarity = 0.5560
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5643
# soham,mmm: Similarity = 0.5168
# soham newww : Similarity = 0.5522
# Somchandra Samanta: Similarity = 0.5004
# Som: Similarity = 0.5422
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5883
# soham,mmm: Similarity = 0.5427
# soham newww : Similarity = 0.5745
# Somchandra Samanta: Similarity = 0.5202
# Som: Similarity = 0.5727
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# soham: Similarity = 0.5805
# soham,mmm: Similarity = 0.5392
# soham newww : Similarity = 0.5658
# Somchandra Samanta: Similarity = 0.5283
# Som: Similarity = 0.5855
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5682
# soham,mmm: Similarity = 0.5335
# soham newww : Similarity = 0.5475
# Somchandra Samanta: Similarity = 0.4970
# Som: Similarity = 0.5563
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5574
# soham,mmm: Similarity = 0.5261
# soham newww : Similarity = 0.5359
# Somchandra Samanta: Similarity = 0.5067
# Som: Similarity = 0.5572
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5661
# soham,mmm: Similarity = 0.5312
# soham newww : Similarity = 0.5496
# Somchandra Samanta: Similarity = 0.5063
# Som: Similarity = 0.5595
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5560
# soham,mmm: Similarity = 0.5162
# soham newww : Similarity = 0.5336
# Somchandra Samanta: Similarity = 0.4840
# Som: Similarity = 0.5497
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5377
# soham,mmm: Similarity = 0.5110
# soham newww : Similarity = 0.5276
# Somchandra Samanta: Similarity = 0.4956
# Som: Similarity = 0.5478
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5917
# soham,mmm: Similarity = 0.5505
# soham newww : Similarity = 0.5827
# Somchandra Samanta: Similarity = 0.5226
# Som: Similarity = 0.5736
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5917
# soham,mmm: Similarity = 0.5505
# soham newww : Similarity = 0.5827
# Somchandra Samanta: Similarity = 0.5226
# Som: Similarity = 0.5736
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5717
# soham,mmm: Similarity = 0.5487
# soham newww : Similarity = 0.5774
# Somchandra Samanta: Similarity = 0.5152
# Som: Similarity = 0.5702
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5815
# soham,mmm: Similarity = 0.5584
# soham newww : Similarity = 0.5912
# Somchandra Samanta: Similarity = 0.5300
# Som: Similarity = 0.5820
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5545
# soham,mmm: Similarity = 0.5218
# soham newww : Similarity = 0.5529
# Somchandra Samanta: Similarity = 0.5152
# Som: Similarity = 0.5670
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5399
# soham,mmm: Similarity = 0.5151
# soham newww : Similarity = 0.5400
# Somchandra Samanta: Similarity = 0.4890
# Som: Similarity = 0.5412
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# soham: Similarity = 0.5533
# soham,mmm: Similarity = 0.5206
# soham newww : Similarity = 0.5503
# Somchandra Samanta: Similarity = 0.4914
# Som: Similarity = 0.5506
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5769
# soham,mmm: Similarity = 0.5386
# soham newww : Similarity = 0.5710
# Somchandra Samanta: Similarity = 0.5023
# Som: Similarity = 0.5585
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5717
# soham,mmm: Similarity = 0.5377
# soham newww : Similarity = 0.5718
# Somchandra Samanta: Similarity = 0.5148
# Som: Similarity = 0.5775
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5748
# soham,mmm: Similarity = 0.5476
# soham newww : Similarity = 0.5788
# Somchandra Samanta: Similarity = 0.5189
# Som: Similarity = 0.5702
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5517
# soham,mmm: Similarity = 0.5226
# soham newww : Similarity = 0.5535
# Somchandra Samanta: Similarity = 0.5089
# Som: Similarity = 0.5603
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5597
# soham,mmm: Similarity = 0.5306
# soham newww : Similarity = 0.5732
# Somchandra Samanta: Similarity = 0.5241
# Som: Similarity = 0.5750
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5604
# soham,mmm: Similarity = 0.5197
# soham newww : Similarity = 0.5575
# Somchandra Samanta: Similarity = 0.5201
# Som: Similarity = 0.5708
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5347
# soham,mmm: Similarity = 0.5170
# soham newww : Similarity = 0.5413
# Somchandra Samanta: Similarity = 0.4883
# Som: Similarity = 0.5355
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5797
# soham,mmm: Similarity = 0.5492
# soham newww : Similarity = 0.5735
# Somchandra Samanta: Similarity = 0.5141
# Som: Similarity = 0.5699
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5797
# soham,mmm: Similarity = 0.5492
# soham newww : Similarity = 0.5735
# Somchandra Samanta: Similarity = 0.5141
# Som: Similarity = 0.5699
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5498
# soham,mmm: Similarity = 0.5217
# soham newww : Similarity = 0.5425
# Somchandra Samanta: Similarity = 0.4878
# Som: Similarity = 0.5393
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5381
# soham,mmm: Similarity = 0.5183
# soham newww : Similarity = 0.5530
# Somchandra Samanta: Similarity = 0.4967
# Som: Similarity = 0.5458
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5856
# soham,mmm: Similarity = 0.5627
# soham newww : Similarity = 0.5918
# Somchandra Samanta: Similarity = 0.5286
# Som: Similarity = 0.5776
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5552
# soham,mmm: Similarity = 0.5362
# soham newww : Similarity = 0.5584
# Somchandra Samanta: Similarity = 0.5010
# Som: Similarity = 0.5469
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5480
# soham,mmm: Similarity = 0.5261
# soham newww : Similarity = 0.5569
# Somchandra Samanta: Similarity = 0.4968
# Som: Similarity = 0.5457
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5623
# soham,mmm: Similarity = 0.5391
# soham newww : Similarity = 0.5757
# Somchandra Samanta: Similarity = 0.5093
# Som: Similarity = 0.5555
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5453
# soham,mmm: Similarity = 0.5191
# soham newww : Similarity = 0.5589
# Somchandra Samanta: Similarity = 0.4978
# Som: Similarity = 0.5560
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5569
# soham,mmm: Similarity = 0.5288
# soham newww : Similarity = 0.5680
# Somchandra Samanta: Similarity = 0.5085
# Som: Similarity = 0.5648
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5627
# soham,mmm: Similarity = 0.5340
# soham newww : Similarity = 0.5711
# Somchandra Samanta: Similarity = 0.5106
# Som: Similarity = 0.5627
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5627
# soham,mmm: Similarity = 0.5340
# soham newww : Similarity = 0.5711
# Somchandra Samanta: Similarity = 0.5106
# Som: Similarity = 0.5627
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# soham: Similarity = 0.5712
# soham,mmm: Similarity = 0.5423
# soham newww : Similarity = 0.5886
# Somchandra Samanta: Similarity = 0.5100
# Som: Similarity = 0.5698
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5690
# soham,mmm: Similarity = 0.5369
# soham newww : Similarity = 0.5676
# Somchandra Samanta: Similarity = 0.5094
# Som: Similarity = 0.5656
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5637
# soham,mmm: Similarity = 0.5433
# soham newww : Similarity = 0.5774
# Somchandra Samanta: Similarity = 0.5125
# Som: Similarity = 0.5674
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5582
# soham,mmm: Similarity = 0.5334
# soham newww : Similarity = 0.5643
# Somchandra Samanta: Similarity = 0.4990
# Som: Similarity = 0.5596
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5671
# soham,mmm: Similarity = 0.5337
# soham newww : Similarity = 0.5736
# Somchandra Samanta: Similarity = 0.5199
# Som: Similarity = 0.5711
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5561
# soham,mmm: Similarity = 0.5272
# soham newww : Similarity = 0.5552
# Somchandra Samanta: Similarity = 0.4989
# Som: Similarity = 0.5583
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5708
# soham,mmm: Similarity = 0.5338
# soham newww : Similarity = 0.5734
# Somchandra Samanta: Similarity = 0.5119
# Som: Similarity = 0.5626
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# soham: Similarity = 0.5433
# soham,mmm: Similarity = 0.5272
# soham newww : Similarity = 0.5517
# Somchandra Samanta: Similarity = 0.4879
# Som: Similarity = 0.5408
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5498
# soham,mmm: Similarity = 0.5220
# soham newww : Similarity = 0.5509
# Somchandra Samanta: Similarity = 0.5094
# Som: Similarity = 0.5630
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5495
# soham,mmm: Similarity = 0.5240
# soham newww : Similarity = 0.5501
# Somchandra Samanta: Similarity = 0.4979
# Som: Similarity = 0.5486
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# soham: Similarity = 0.5451
# soham,mmm: Similarity = 0.5139
# soham newww : Similarity = 0.5464
# Somchandra Samanta: Similarity = 0.4961
# Som: Similarity = 0.5452
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5678
# soham,mmm: Similarity = 0.5377
# soham newww : Similarity = 0.5707
# Somchandra Samanta: Similarity = 0.5067
# Som: Similarity = 0.5647
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5628
# soham,mmm: Similarity = 0.5321
# soham newww : Similarity = 0.5598
# Somchandra Samanta: Similarity = 0.4912
# Som: Similarity = 0.5527
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5583
# soham,mmm: Similarity = 0.5235
# soham newww : Similarity = 0.5569
# Somchandra Samanta: Similarity = 0.5041
# Som: Similarity = 0.5667
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5583
# soham,mmm: Similarity = 0.5235
# soham newww : Similarity = 0.5569
# Somchandra Samanta: Similarity = 0.5041
# Som: Similarity = 0.5667
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5596
# soham,mmm: Similarity = 0.5319
# soham newww : Similarity = 0.5618
# Somchandra Samanta: Similarity = 0.5055
# Som: Similarity = 0.5619
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# soham: Similarity = 0.5780
# soham,mmm: Similarity = 0.5467
# soham newww : Similarity = 0.5873
# Somchandra Samanta: Similarity = 0.5186
# Som: Similarity = 0.5682
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5537
# soham,mmm: Similarity = 0.5161
# soham newww : Similarity = 0.5561
# Somchandra Samanta: Similarity = 0.4980
# Som: Similarity = 0.5550
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5725
# soham,mmm: Similarity = 0.5413
# soham newww : Similarity = 0.5778
# Somchandra Samanta: Similarity = 0.5269
# Som: Similarity = 0.5769
# soham newww 's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# soham: Similarity = 0.5695
# soham,mmm: Similarity = 0.5339
# soham newww : Similarity = 0.5676
# Somchandra Samanta: Similarity = 0.5123
# Som: Similarity = 0.5622
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5802
# soham,mmm: Similarity = 0.5443
# soham newww : Similarity = 0.5756
# Somchandra Samanta: Similarity = 0.5277
# Som: Similarity = 0.5752
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5749
# soham,mmm: Similarity = 0.5439
# soham newww : Similarity = 0.5692
# Somchandra Samanta: Similarity = 0.5258
# Som: Similarity = 0.5775
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5779
# soham,mmm: Similarity = 0.5475
# soham newww : Similarity = 0.5758
# Somchandra Samanta: Similarity = 0.5208
# Som: Similarity = 0.5728
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5694
# soham,mmm: Similarity = 0.5363
# soham newww : Similarity = 0.5538
# Somchandra Samanta: Similarity = 0.5226
# Som: Similarity = 0.5782
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5802
# soham,mmm: Similarity = 0.5481
# soham newww : Similarity = 0.5657
# Somchandra Samanta: Similarity = 0.5263
# Som: Similarity = 0.5784
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5701
# soham,mmm: Similarity = 0.5346
# soham newww : Similarity = 0.5520
# Somchandra Samanta: Similarity = 0.5009
# Som: Similarity = 0.5519
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5615
# soham,mmm: Similarity = 0.5240
# soham newww : Similarity = 0.5383
# Somchandra Samanta: Similarity = 0.4862
# Som: Similarity = 0.5434
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5731
# soham,mmm: Similarity = 0.5376
# soham newww : Similarity = 0.5665
# Somchandra Samanta: Similarity = 0.5112
# Som: Similarity = 0.5611
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5458
# soham,mmm: Similarity = 0.5134
# soham newww : Similarity = 0.5238
# Somchandra Samanta: Similarity = 0.4661
# Som: Similarity = 0.5132
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5718
# soham,mmm: Similarity = 0.5233
# soham newww : Similarity = 0.5483
# Somchandra Samanta: Similarity = 0.4974
# Som: Similarity = 0.5490
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# soham: Similarity = 0.5718
# soham,mmm: Similarity = 0.5233
# soham newww : Similarity = 0.5483
# Somchandra Samanta: Similarity = 0.4974
# Som: Similarity = 0.5490
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5875
# soham,mmm: Similarity = 0.5360
# soham newww : Similarity = 0.5649
# Somchandra Samanta: Similarity = 0.5106
# Som: Similarity = 0.5752
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# soham: Similarity = 0.5899
# soham,mmm: Similarity = 0.5404
# soham newww : Similarity = 0.5720
# Somchandra Samanta: Similarity = 0.5219
# Som: Similarity = 0.5761
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# soham: Similarity = 0.5611
# soham,mmm: Similarity = 0.5231
# soham newww : Similarity = 0.5574
# Somchandra Samanta: Similarity = 0.4965
# Som: Similarity = 0.5414
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# soham: Similarity = 0.5689
# soham,mmm: Similarity = 0.5205
# soham newww : Similarity = 0.5545
# Somchandra Samanta: Similarity = 0.4955
# Som: Similarity = 0.5493
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5645
# soham,mmm: Similarity = 0.5189
# soham newww : Similarity = 0.5492
# Somchandra Samanta: Similarity = 0.4943
# Som: Similarity = 0.5427
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# soham: Similarity = 0.5463
# soham,mmm: Similarity = 0.5008
# soham newww : Similarity = 0.5285
# Somchandra Samanta: Similarity = 0.4725
# Som: Similarity = 0.5224
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# soham: Similarity = 0.5698
# soham,mmm: Similarity = 0.5363
# soham newww : Similarity = 0.5649
# Somchandra Samanta: Similarity = 0.5057
# Som: Similarity = 0.5534
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# soham: Similarity = 0.5825
# soham,mmm: Similarity = 0.5373
# soham newww : Similarity = 0.5638
# Somchandra Samanta: Similarity = 0.5014
# Som: Similarity = 0.5549
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5633
# soham,mmm: Similarity = 0.5150
# soham newww : Similarity = 0.5498
# Somchandra Samanta: Similarity = 0.4922
# Som: Similarity = 0.5430
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# soham: Similarity = 0.5681
# soham,mmm: Similarity = 0.5325
# soham newww : Similarity = 0.5568
# Somchandra Samanta: Similarity = 0.4983
# Som: Similarity = 0.5469
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# soham: Similarity = 0.6042
# soham,mmm: Similarity = 0.5640
# soham newww : Similarity = 0.5970
# Somchandra Samanta: Similarity = 0.5295
# Som: Similarity = 0.5885
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# soham: Similarity = 0.5720
# soham,mmm: Similarity = 0.5398
# soham newww : Similarity = 0.5722
# Somchandra Samanta: Similarity = 0.5189
# Som: Similarity = 0.5734
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# soham: Similarity = 0.6062
# soham,mmm: Similarity = 0.5709
# soham newww : Similarity = 0.6055
# Somchandra Samanta: Similarity = 0.5273
# Som: Similarity = 0.5818
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# soham: Similarity = 0.5844
# soham,mmm: Similarity = 0.5484
# soham newww : Similarity = 0.5782
# Somchandra Samanta: Similarity = 0.5129
# Som: Similarity = 0.5757
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# soham: Similarity = 0.5710
# soham,mmm: Similarity = 0.5291
# soham newww : Similarity = 0.5549
# Somchandra Samanta: Similarity = 0.4978
# Som: Similarity = 0.5528
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# soham: Similarity = 0.5681
# soham,mmm: Similarity = 0.5293
# soham newww : Similarity = 0.5560
# Somchandra Samanta: Similarity = 0.5039
# Som: Similarity = 0.5569
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# soham: Similarity = 0.5845
# soham,mmm: Similarity = 0.5495
# soham newww : Similarity = 0.5797
# Somchandra Samanta: Similarity = 0.5281
# Som: Similarity = 0.5741
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# soham: Similarity = 0.5651
# soham,mmm: Similarity = 0.5359
# soham newww : Similarity = 0.5603
# Somchandra Samanta: Similarity = 0.5163
# Som: Similarity = 0.5532
# soham's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# soham: Similarity = 0.5756
# soham,mmm: Similarity = 0.5458
# soham newww : Similarity = 0.5747
# Somchandra Samanta: Similarity = 0.5327
# Som: Similarity = 0.5784
# Som's attendance already marked today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# soham: Similarity = 0.5633
# soham,mmm: Similarity = 0.5346
# soham newww : Similarity = 0.5655
# Somchandra Samanta: Similarity = 0.5133
# Som: Similarity = 0.5612
# soham newww 's attendance already marked today.
